# %% [markdown]
# ## [NOTE]
# - LANGCHAIN_TRACING_V2=true
#
# LANGCHAIN_ENDPOINT="https://api.smith.langchain.com"
#
#
# LANGCHAIN_API_KEY="<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>"
#
# LANGCHAIN_PROJECT="test_jju_kongnamhyun"

# %%
pip install -qU langchain langchain-openai

# %%
import os

os.environ["OPENAI_API_KEY"] = "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"

os.environ["LANGCHAIN_API_KEY"] = "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"
os.environ["LANGCHAIN_TRACING_V2"] = "true"
os.environ["LANGCHAIN_ENDPOINT"] = "https://api.smith.langchain.com"
os.environ["LANGCHAIN_PROJECT"] = "test_jju_kongnamhyun"

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI()
llm.invoke("가슴 운동 추천")

# %%
from langchain_openai import ChatOpenAI

llm = ChatOpenAI(
    model="gpt-4o",
    temperature=0,
    max_tokens=None,
    timeout=None,
    max_retries=2,
    api_key=os.environ["OPENAI_API_KEY"],
)

# %%
Response = llm.invoke("서울의 수도는?")

# %%
Response
